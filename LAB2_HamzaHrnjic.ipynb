# %% [markdown]
# # LAB_2

# %%
# ============================================================================
# LABORATORIJSKA VJEŽBA 2: Newton-Raphsonov algoritam
# Predmet: Optimizacija resursa
# Univerzitet u Sarajevu - Elektrotehnički fakultet
# ============================================================================

"""
# 📚 Uvod

Ova laboratorijska vježba demonstrira implementaciju i primjenu
**Newton-Raphsonovog algoritma** za traženje lokalnih ekstrema funkcija.

## Teorijska osnova

Newton-Raphsonov algoritam koristi rekurzivnu relaciju:

$$x_{k+1} = x_k - \\frac{f'(x_k)}{f''(x_k)}$$

### Uslov zaustavljanja:
- Maksimalan broj iteracija N, ili
- $|f(x_{k+1}) - f(x_k)| < \\varepsilon$
"""

# ============================================================================
# INSTALACIJA I IMPORTOVANJE BIBLIOTEKA
# ============================================================================

# Instaliramo plotly ako nije instaliran
try:
    import plotly.graph_objects as go
except ImportError:
    print("Instaliram plotly...")
    import subprocess
    subprocess.check_call(['pip', 'install', 'plotly', '--break-system-packages'])
    import plotly.graph_objects as go

import numpy as np
import math as m
import random
from typing import Callable, Tuple, List

print("✅ Sve biblioteke uspješno učitane!")

# ============================================================================
# ZADATAK 1: IMPLEMENTACIJA NEWTON-RAPHSON ALGORITMA
# ============================================================================

"""
# 🔧 Zadatak 1: Implementacija Newton-Raphson algoritma

Implementiramo funkciju `NR` koja prima:
- `f`: kriterijska funkcija
- `df`: prvi izvod funkcije
- `ddf`: drugi izvod funkcije
- `x0`: početna tačka pretraživanja
- `N`: maksimalan broj iteracija
- `eps`: minimalna promjena po vrijednosti funkcije
"""

def NR(f: Callable, df: Callable, ddf: Callable,
       x0: float, N: int, eps: float) -> Tuple[float, List[float], int]:
    """
    Newton-Raphson algoritam za traženje lokalnog ekstrema funkcije.
    """
    x_current = x0
    history = [x0]

    for k in range(N):
        ddf_val = ddf(x_current)

        # AKO JE DRUGI IZVOD BLIZU NULE - POMJERIMO SE MALO!
        if abs(ddf_val) < 1e-12:
            print(f"⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji {k}!")
            print(f"   Pomjeram se za random offset...")

            # Random pomjeranje za ±0.01
            offset = random.choice([-0.01, 0.01])  # ili random.uniform(-0.01, 0.01)
            x_current = x_current + offset
            history.append(x_current)

            # Nastavi sa sljedećom iteracijom
            continue

        # Newton-Raphson formula
        x_next = x_current - df(x_current) / ddf_val
        history.append(x_next)

        # Provjeravamo uslov zaustavljanja
        if abs(f(x_next) - f(x_current)) < eps:
            print(f"✓ Konvergencija postignuta nakon {k+1} iteracija")
            print(f"  Početna tačka: x0 = {x0:.6f}")
            print(f"  Finalna tačka: x* = {x_next:.6f}")
            print(f"  Vrijednost funkcije: f(x*) = {f(x_next):.6f}")
            return x_next, history, k + 1

        x_current = x_next

    print(f"⚠️ Dostignut maksimalan broj iteracija ({N})")
    print(f"  Početna tačka: x0 = {x0:.6f}")
    print(f"  Finalna tačka: x* = {x_current:.6f}")
    print(f"  Vrijednost funkcije: f(x*) = {f(x_current):.6f}")
    return x_current, history, N


# ============================================================================
# ZADATAK 2: DEFINICIJE TEST FUNKCIJA I NJIHOVIH IZVODA
# ============================================================================

"""
# 📊 Zadatak 2: Test funkcije

Definirat ćemo sve test funkcije i njihove izvode:

1. $f_1(x) = 3x^2 - 1$
2. $f_2(x) = -(16x^2 - 24x + 5)e^{-x}$
3. $f_3(x) = \\sin(x) + \\sin(\\frac{10x}{3})$
4. $f_4(x) = e^{-x}$
"""

# Funkcija 1: f(x) = 3x^2 - 1
def f1(x):
    return 3*x**2 - 1

def df1(x):
    return 6*x

def ddf1(x):
    return 6

# Funkcija 2: f(x) = -(16x^2 - 24x + 5)e^(-x)
def f2(x):
    return -(16*x**2 - 24*x + 5) * np.exp(-x)

def df2(x):
    # f'(x) = -[(32x - 24)e^(-x) - (16x^2 - 24x + 5)e^(-x)]
    # f'(x) = -e^(-x)[32x - 24 - 16x^2 + 24x - 5]
    # f'(x) = -e^(-x)[-16x^2 + 56x - 29]
    return -np.exp(-x) * (-16*x**2 + 56*x - 29)

def ddf2(x):
    # f''(x) = -e^(-x)[(-32x + 56) - (-16x^2 + 56x - 29)]
    # f''(x) = -e^(-x)[-32x + 56 + 16x^2 - 56x + 29]
    # f''(x) = -e^(-x)[16x^2 - 88x + 85]
    return -np.exp(-x) * (16*x**2 - 88*x + 85)

# Funkcija 3: f(x) = sin(x) + sin(10x/3)
def f3(x):
    return np.sin(x) + np.sin(10*x/3)

def df3(x):
    return np.cos(x) + (10/3)*np.cos(10*x/3)

def ddf3(x):
    return -np.sin(x) - (100/9)*np.sin(10*x/3)

# Funkcija 4: f(x) = e^(-x)
def f4(x):
    return np.exp(-x)

def df4(x):
    return -np.exp(-x)

def ddf4(x):
    return np.exp(-x)

print("✅ Sve funkcije i njihovi izvodi definirani!")


# ============================================================================
# FUNKCIJA ZA VIZUALIZACIJU
# ============================================================================

"""
# 📈 Funkcija za vizualizaciju rezultata

Kreiraćemo pomocnu funkciju koja će crtati:
- Grafik funkcije (crna linija)
- Lokalne ekstreme (crveni kružići ◦)
- Pronađene tačke Newton-Raphson algoritmom (zeleni križići ×)
"""

def plot_function_with_results(f, x_range, nr_points, local_extrema,
                                title, x0_values):
    """
    Crta funkciju sa označenim lokalnim ekstremima i NR rezultatima.

    Parametri:
    ----------
    f : funkcija
        Funkcija koju crtamo
    x_range : tuple
        (x_min, x_max) opseg za crtanje
    nr_points : list
        Lista tačaka pronađenih NR algoritmom
    local_extrema : list
        Lista lokalnih ekstrema (x koordinate)
    title : str
        Naslov grafika
    x0_values : list
        Lista početnih tačaka
    """
    # Generišemo x vrijednosti za crtanje
    x = np.linspace(x_range[0], x_range[1], 1000)

    # Računamo y vrijednosti
    # Pazimo na funkcije koje mogu imati probleme (npr. dijeljenje sa nulom)
    try:
        y = f(x)
    except:
        # Ako ima problema, računamo tačku po tačku
        y = np.array([f(xi) for xi in x])

    # Kreiramo figuru
    fig = go.Figure()

    # Dodajemo glavnu liniju funkcije
    fig.add_trace(go.Scatter(
        x=x, y=y,
        mode='lines',
        name='f(x)',
        line=dict(color='black', width=2)
    ))

    # Dodajemo lokalne ekstreme (crveni kružići)
    if local_extrema:
        x_ext = np.array(local_extrema)
        y_ext = np.array([f(xi) for xi in x_ext])
        fig.add_trace(go.Scatter(
            x=x_ext, y=y_ext,
            mode='markers',
            name='Lokalni ekstremi',
            marker=dict(color='red', size=12, symbol='circle-open', line=dict(width=2))
        ))

    # Dodajemo NR rezultate (zeleni križići)
    if nr_points:
        x_nr = np.array(nr_points)
        y_nr = np.array([f(xi) for xi in x_nr])
        fig.add_trace(go.Scatter(
            x=x_nr, y=y_nr,
            mode='markers',
            name='Newton-Raphson rezultati',
            marker=dict(color='green', size=12, symbol='x', line=dict(width=2))
        ))

    # Postavljamo layout
    fig.update_layout(
        title=title,
        xaxis_title='x',
        yaxis_title='f(x)',
        xaxis=dict(showgrid=True, gridwidth=1, gridcolor='LightGray'),
        yaxis=dict(showgrid=True, gridwidth=1, gridcolor='LightGray'),
        plot_bgcolor='white',
        hovermode='closest',
        showlegend=True,
        width=900,
        height=600
    )

    fig.show()

    # Ispis rezultata
    print(f"\n{'='*60}")
    print(f"Rezime za funkciju: {title}")
    print(f"{'='*60}")
    print(f"Početne tačke: {x0_values}")
    print(f"Pronađene tačke: {[f'{x:.6f}' for x in nr_points]}")
    if local_extrema:
        print(f"Pravi lokalni ekstremi: {[f'{x:.6f}' for x in local_extrema]}")
    print(f"{'='*60}\n")


# ============================================================================
# TEST FUNKCIJA 1: f(x) = 3x^2 - 1
# ============================================================================

"""
# 🔬 Test 1: $f_1(x) = 3x^2 - 1$

### Analiza:
- Ovo je kvadratna funkcija (parabola)
- Ima jedan ekstrem u x = 0 (minimum)
- f'(x) = 6x
- f''(x) = 6

### Testiranje sa početnim tačkama: x₀ ∈ {1, 10}
"""

print("\n" + "="*70)
print("TEST 1: f(x) = 3x² - 1")
print("="*70)

x0_list_1 = [1, 10]
nr_results_1 = []

for x0 in x0_list_1:
    print(f"\n--- Početna tačka x0 = {x0} ---")
    x_opt, history, iters = NR(f1, df1, ddf1, x0=x0, N=100, eps=1e-6)
    nr_results_1.append(x_opt)

# Crtamo grafik
local_extrema_1 = [0]  # Jedini ekstrem je u x=0
plot_function_with_results(
    f=f1,
    x_range=(-2, 12),
    nr_points=nr_results_1,
    local_extrema=local_extrema_1,
    title='$f_1(x) = 3x^2 - 1$',
    x0_values=x0_list_1
)


# ============================================================================
# TEST FUNKCIJA 2: f(x) = -(16x^2 - 24x + 5)e^(-x)
# ============================================================================

"""
# 🔬 Test 2: $f_2(x) = -(16x^2 - 24x + 5)e^{-x}$

### Analiza:
- Složenija funkcija sa eksponencijalnim članom
- Ima lokalne ekstreme koje trebamo pronaći
- Testiramo sa x₀ ∈ {0.5, 2}
"""

print("\n" + "="*70)
print("TEST 2: f(x) = -(16x² - 24x + 5)e^(-x)")
print("="*70)

x0_list_2 = [0.5, 2]
nr_results_2 = []

for x0 in x0_list_2:
    print(f"\n--- Početna tačka x0 = {x0} ---")
    x_opt, history, iters = NR(f2, df2, ddf2, x0=x0, N=100, eps=1e-6)
    nr_results_2.append(x_opt)

# Za lokalne ekstreme, možemo ih pronaći numerički ili analitički
# Rješavamo f'(x) = 0: -e^(-x)[-16x^2 + 56x - 29] = 0
# -16x^2 + 56x - 29 = 0
# x = (56 ± sqrt(56^2 - 4*16*29)) / (2*16)
discriminant = 56**2 - 4*16*29
x_ext1 = (56 + np.sqrt(discriminant)) / 32
x_ext2 = (56 - np.sqrt(discriminant)) / 32
local_extrema_2 = [x_ext2, x_ext1]

plot_function_with_results(
    f=f2,
    x_range=(-1, 5),
    nr_points=nr_results_2,
    local_extrema=local_extrema_2,
    title='$f_2(x) = -(16x^2 - 24x + 5)e^{-x}$',
    x0_values=x0_list_2
)


# ============================================================================
# TEST FUNKCIJA 3: f(x) = sin(x) + sin(10x/3)
# ============================================================================

"""
# 🔬 Test 3: $f_3(x) = \\sin(x) + \\sin(\\frac{10x}{3})$

### Analiza:
- Trigonometrijska funkcija sa periodicnim svojstvima
- Ima više lokalnih ekstrema
- Testiramo sa x₀ ∈ {3, 6, 7}
"""

print("\n" + "="*70)
print("TEST 3: f(x) = sin(x) + sin(10x/3)")
print("="*70)

x0_list_3 = [2, 3, 6, 7]
nr_results_3 = []

for x0 in x0_list_3:
    print(f"\n--- Početna tačka x0 = {x0} ---")
    x_opt, history, iters = NR(f3, df3, ddf3, x0=x0, N=100, eps=1e-6)
    nr_results_3.append(x_opt)

# Lokalne ekstreme pronalazimo numerički
# Tražimo gdje je df3(x) ≈ 0 u opsegu
x_test = np.linspace(0, 10, 10000)
df3_vals = df3(x_test)
# Pronalazimo gdje derivacija mijenja predznak
sign_changes = np.where(np.diff(np.sign(df3_vals)))[0]
local_extrema_3 = [x_test[i] for i in sign_changes]

plot_function_with_results(
    f=f3,
    x_range=(0, 10),
    nr_points=nr_results_3,
    local_extrema=local_extrema_3,
    title='$f_3(x) = \\sin(x) + \\sin(\\frac{10x}{3})$',
    x0_values=x0_list_3
)


# ============================================================================
# TEST FUNKCIJA 4: f(x) = e^(-x)
# ============================================================================

"""
# 🔬 Test 4: $f_4(x) = e^{-x}$

### Analiza:
- Eksponencijalna funkcija koja monotono opada
- f'(x) = -e^(-x) < 0 za svako x (monotono opadajuća)
- f''(x) = e^(-x) > 0 za svako x (konveksna)
- **NEMA lokalnih ekstrema!** Funkcija je striktno monotona
- Testiramo sa x₀ ∈ {1, 10}
"""

print("\n" + "="*70)
print("TEST 4: f(x) = e^(-x)")
print("="*70)

x0_list_4 = [1, 10]
nr_results_4 = []

for x0 in x0_list_4:
    print(f"\n--- Početna tačka x0 = {x0} ---")
    x_opt, history, iters = NR(f4, df4, ddf4, x0=x0, N=100, eps=1e-6)
    nr_results_4.append(x_opt)

# Nema lokalnih ekstrema - funkcija je monotona
local_extrema_4 = []

plot_function_with_results(
    f=f4,
    x_range=(-1, 12),
    nr_points=nr_results_4,
    local_extrema=local_extrema_4,
    title='$f_4(x) = e^{-x}$',
    x0_values=x0_list_4
)


# ============================================================================
# ZAKLJUČCI
# ============================================================================

"""
# 📝 Zaključci i analiza rezultata

## Opažanja po funkcijama:

### Funkcija 1: $f_1(x) = 3x^2 - 1$
- ✅ Algoritam uspješno pronalazi minimum u x = 0
- Konvergencija je brza za obje početne tačke
- Kvadratna funkcija je idealan slučaj za Newton-Raphson

### Funkcija 2: $f_2(x) = -(16x^2 - 24x + 5)e^{-x}$
- ✅ Algoritam pronalazi različite lokalne ekstreme zavisno od početne tačke
- Pokazuje važnost izbora početne tačke
- Oba rezultata su validni lokalni ekstremi

### Funkcija 3: $f_3(x) = \\sin(x) + \\sin(\\frac{10x}{3})$
- ✅ Funkcija ima mnogo lokalnih ekstrema
- Algoritam konvergira ka najbližem ekstremu od početne tačke
- Demonstrira ograničenje metode - nalazi samo lokalne, ne i globalne ekstreme

### Funkcija 4: $f_4(x) = e^{-x}$
- ⚠️ Funkcija NEMA lokalne ekstreme (striktno monotona)
- Algoritam ne može da konvergira jer tražimo ekstrem koji ne postoji
- Ovo ilustruje kada metoda nije primjenjiva

## Opšti zaključci:

1. **Brzina konvergencije**: Newton-Raphson metoda ima kvadratnu konvergenciju
   kod "dobrih" funkcija (glatke, konveksne/konkavne)

2. **Zavisnost od početne tačke**: Različite početne tačke mogu dovesti do
   različitih lokalnih ekstrema

3. **Ograničenja metode**:
   - Nalazi samo lokalne ekstreme, ne garantuje globalni ekstrem
   - Zahtijeva da f''(x) ≠ 0
   - Ne radi na monotonim funkcijama
   - Može divergirati ili oscilirati sa lošim početnim tačkama

4. **Primjenjivost**: Metoda je efikasna za funkcije sa jasno definisanim
   lokalnim ekstremima i kada imamo dobru procjenu početne tačke

## Preporuke:

- Za pronalaženje globalnog ekstrema, kombinovati sa metodama globalnog pretraživanja
- Koristiti više početnih tačaka i porediti rezultate
- Provjeravati prirodu ekstrema (minimum/maximum) preko f''(x)
- Dodati dodatne provjere za robusnost (npr. line search)
"""

print("\n" + "="*70)
print("KRAJ LABORATORIJSKE VJEŽBE")
print("="*70)
print("\n✅ Svi zadaci uspješno urađeni!")
print("📊 Grafici prikazani koristeći Plotly")
print("📝 Rezultati analizirani i dokumentovani")
# Out:
# ✅ Sve biblioteke uspješno učitane!
# ✅ Sve funkcije i njihovi izvodi definirani!
#
# ======================================================================
# TEST 1: f(x) = 3x² - 1
# ======================================================================
#
# --- Početna tačka x0 = 1 ---
# ✓ Konvergencija postignuta nakon 2 iteracija
#   Početna tačka: x0 = 1.000000
#   Finalna tačka: x* = 0.000000
#   Vrijednost funkcije: f(x*) = -1.000000
#
# --- Početna tačka x0 = 10 ---
# ✓ Konvergencija postignuta nakon 2 iteracija
#   Početna tačka: x0 = 10.000000
#   Finalna tačka: x* = 0.000000
#   Vrijednost funkcije: f(x*) = -1.000000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3d79975d-c125-421a-8709-779691f03f0f" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d79975d-c125-421a-8709-779691f03f0f")) {                    Plotly.newPlot(                        "3d79975d-c125-421a-8709-779691f03f0f",                        [{"line":{"color":"black","width":2},"mode":"lines","name":"f(x)","x":[-2.0,-1.985985985985986,-1.971971971971972,-1.957957957957958,-1.9439439439439439,-1.92992992992993,-1.915915915915916,-1.901901901901902,-1.887887887887888,-1.8738738738738738,-1.85985985985986,-1.8458458458458458,-1.8318318318318318,-1.8178178178178177,-1.8038038038038038,-1.7897897897897899,-1.7757757757757757,-1.7617617617617618,-1.7477477477477477,-1.7337337337337337,-1.7197197197197198,-1.7057057057057057,-1.6916916916916918,-1.6776776776776776,-1.6636636636636637,-1.6496496496496498,-1.6356356356356356,-1.6216216216216215,-1.6076076076076076,-1.5935935935935936,-1.5795795795795795,-1.5655655655655656,-1.5515515515515514,-1.5375375375375375,-1.5235235235235236,-1.5095095095095095,-1.4954954954954955,-1.4814814814814814,-1.4674674674674675,-1.4534534534534536,-1.4394394394394394,-1.4254254254254253,-1.
-0.12312312312312312,-0.11711711711711714,-0.11111111111111116,-0.10510510510510507,-0.09909909909909909,-0.0930930930930931,-0.08708708708708712,-0.08108108108108114,-0.07507507507507505,-0.06906906906906907,-0.06306306306306309,-0.0570570570570571,-0.05105105105105101,-0.04504504504504503,-0.03903903903903905,-0.033033033033033066,-0.027027027027027084,-0.02102102102102099,-0.01501501501501501,-0.009009009009009028,-0.0030030030 ...
# ============================================================
# Rezime za funkciju: $f_2(x) = -(16x^2 - 24x + 5)e^{-x}$
# ============================================================
# Početne tačke: [0.5, 2]
# Pronađene tačke: ['0.631966', '2.868034']
# Pravi lokalni ekstremi: ['0.631966', '2.868034']
# ============================================================
#
#
# ======================================================================
# TEST 3: f(x) = sin(x) + sin(10x/3)
# ======================================================================
#
# --- Početna tačka x0 = 2 ---
# ✓ Konvergencija postignuta nakon 5 iteracija
#   Početna tačka: x0 = 2.000000
#   Finalna tačka: x* = 2.296091
#   Vrijednost funkcije: f(x*) = 1.728302
#
# --- Početna tačka x0 = 3 ---
# ✓ Konvergencija postignuta nakon 5 iteracija
#   Početna tačka: x0 = 3.000000
#   Finalna tačka: x* = 3.387252
#   Vrijednost funkcije: f(x*) = -1.199921
#
# --- Početna tačka x0 = 6 ---
# ✓ Konvergencija postignuta nakon 3 iteracija
#   Početna tačka: x0 = 6.000000
#   Finalna tačka: x* = 6.217309
#   Vrijednost funkcije: f(x*) = 0.888315
#
# --- Početna tačka x0 = 7 ---
# ✓ Konvergencija postignuta nakon 1 iteracija
#   Početna tačka: x0 = 7.000000
#   Finalna tačka: x* = 7.000149
#   Vrijednost funkcije: f(x*) = -0.316996
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1723ad33-44b4-40ed-bcfc-6d8448c61033" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1723ad33-44b4-40ed-bcfc-6d8448c61033")) {                    Plotly.newPlot(                        "1723ad33-44b4-40ed-bcfc-6d8448c61033",                        [{"line":{"color":"black","width":2},"mode":"lines","name":"f(x)","x":[0.0,0.01001001001001001,0.02002002002002002,0.03003003003003003,0.04004004004004004,0.050050050050050046,0.06006006006006006,0.07007007007007007,0.08008008008008008,0.09009009009009009,0.10010010010010009,0.11011011011011011,0.12012012012012012,0.13013013013013014,0.14014014014014015,0.15015015015015015,0.16016016016016016,0.17017017017017017,0.18018018018018017,0.19019019019019018,0.20020020020020018,0.21021021021021022,0.22022022022022023,0.23023023023023023,0.24024024024024024,0.2502502502502503,0.2602602602602603,0.2702702702702703,0.2802802802802803,0.2902902902902903,0.3003003003003003,0.3103103103103103,0.3203203203203203,0.3303303303303303,0.34034034034034033,0.35035035035035034,0.36036036036036034,0.37037037037037035,0.38038038038038036,0.39039039039039036,0.40040040040040037,0.41041041041041043,0.42042042042042044,0.43043043043043044,0.44044044044044045,0.45045045045045046,0.46046046046046046,0.47047047047047047,0.4804804804804805,0.4904904904904905,0.5005005005005005,0.5105105105105106,0.5205205205205206,0.5305305305305306,0.5405405405405406,0.5505505505505506,0.5605605605605606,0.5705705705705706,0.5805805805805806,0.5905905905905906,0.6006006006006006,0.6106106106106106,0.6206206206206206,0.6306306306306306,0.6406406406406406,0.6506506506506506,0.6606606606606606,0.6706706706706707,0.6806806806806807,0.6906906906906907,0.7007007007007007,0.7107107107107107,0.7207207207207207,0.7307307307307307,0.7407407407407407,0.7507507507507507,0.7607607607607607,0.7707707707707707,0.7807807807807807,0.7907907907907907,0.8008008008008007,0.8108108108108109,0.8208208208208209,0.8308308308308309,0.8408408408408409,0.8508508508508509,0.8608608608608609,0.8708708708708709,0.8808808808808809,0.8908908908908909,0.9009009009009009,0.9109109109109109,0.9209209209209209,0.9309309309309309,0.9409409409409409,0.950950950950951,0.960960960960961,0.970970970970971,0.980980980980981,0.990990990990991,1.001001001001001,1.011011011011011,1.021021021021021,1.031031031031031,1.0410410410410411,1.0510510510510511,1.0610610610610611,1.0710710710710711,1.0810810810810811,1.0910910910910911,1.1011011011011012,1.1111111111111112,1.1211211211211212,1.1311311311311312,1.1411411411411412,1.1511511511511512,1.1611611611611612,1.1711711711711712,1.1811811811811812,1.1911911911911912,1.2012012012012012,1.2112112112112112,1.2212212212212212,1.2312312312312312,1.2412412412412412,1.2512512512512513,1.2612612612612613,1.2712712712712713,1.2812812812812813,1.2912912912912913,1.3013013013013013,1.3113113113113113,1.3213213213213213,1.3313313313313313,1.3413413413413413,1.3513513513513513,1.3613613613613613,1.3713713713713713,1.3813813813813813,1.3913913913913913,1.4014014014014013,1.4114114114114114,1.4214214214214214,1.4314314314314314,1.4414414414414414,1.4514514514514514,1.4614614614614614,1.4714714714714714,1.4814814814814814,1.4914914914914914,1.5015015015015014,1.5115115115115114,1.5215215215215214,1.5315315315315314,1.5415415415415414,1.5515515515515514,1.5615615615615615,1.5715715715715715,1.5815815815815815,1.5915915915915915,1.6016016016016015,1.6116116116116117,1.6216216216216217,1.6316316316316317,1.6416416416416417,1.6516516516516517,1.6616616616616617,1.6716716716716717,1.6816816816816818,1.6916916916916918,1.7017017017017018,1.7117117117117118,1.7217217217217218,1.7317317317317318,1.7417417417417418,1.7517517517517518,1.7617 ...
# ============================================================
# Rezime za funkciju: $f_3(x) = \sin(x) + \sin(\frac{10x}{3})$
# ============================================================
# Početne tačke: [2, 3, 6, 7]
# Pronađene tačke: ['2.296091', '3.387252', '6.217309', '7.000149']
# Pravi lokalni ekstremi: ['0.548055', '1.398140', '2.295230', '3.386339', '4.196420', '5.145515', '6.216622', '6.999700', '7.997800', '9.037904', '9.810981']
# ============================================================
#
#
# ======================================================================
# TEST 4: f(x) = e^(-x)
# ======================================================================
#
# --- Početna tačka x0 = 1 ---
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 27!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 28!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 29!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 30!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 31!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 32!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 33!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 34!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 35!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 36!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 37!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 38!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 39!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 40!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 41!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 42!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 43!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 44!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 45!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 46!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 47!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 48!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 49!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 50!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 51!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 52!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 53!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 54!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 55!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 56!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 57!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 58!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 59!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 60!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 61!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 62!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 63!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 64!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 65!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 66!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 67!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 68!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 69!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 70!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 71!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 72!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 73!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 74!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 75!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 76!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 77!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 78!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 79!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 80!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 81!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 82!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 83!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 84!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 85!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 86!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 87!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 88!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 89!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 90!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 91!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 92!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 93!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 94!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 95!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 96!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 97!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 98!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 99!
#    Pomjeram se za random offset...
# ⚠️ Dostignut maksimalan broj iteracija (100)
#   Početna tačka: x0 = 1.000000
#   Finalna tačka: x* = 27.990000
#   Vrijednost funkcije: f(x*) = 0.000000
#
# --- Početna tačka x0 = 10 ---
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 18!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 19!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 20!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 21!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 22!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 23!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 24!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 25!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 26!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 27!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 28!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 29!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 30!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 31!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 32!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 33!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 34!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 35!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 36!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 37!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 38!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 39!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 40!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 41!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 42!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 43!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 44!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 45!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 46!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 47!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 48!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 49!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 50!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 51!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 52!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 53!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 54!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 55!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 56!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 57!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 58!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 59!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 60!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 61!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 62!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 63!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 64!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 65!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 66!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 67!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 68!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 69!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 70!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 71!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 72!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 73!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 74!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 75!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 76!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 77!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 78!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 79!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 80!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 81!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 82!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 83!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 84!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 85!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 86!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 87!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 88!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 89!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 90!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 91!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 92!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 93!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 94!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 95!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 96!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 97!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 98!
#    Pomjeram se za random offset...
# ⚠️ Upozorenje: Drugi izvod blizu nule na iteraciji 99!
#    Pomjeram se za random offset...
# ⚠️ Dostignut maksimalan broj iteracija (100)
#   Početna tačka: x0 = 10.000000
#   Finalna tačka: x* = 28.000000
#   Vrijednost funkcije: f(x*) = 0.000000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c1d6ff16-1828-40e8-9cb1-71433cc7e2e9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1d6ff16-1828-40e8-9cb1-71433cc7e2e9")) {                    Plotly.newPlot(                        "c1d6ff16-1828-40e8-9cb1-71433cc7e2e9",                        [{"line":{"color":"black","width":2},"mode":"lines","name":"f(x)","x":[-1.0,-0.986986986986987,-0.973973973973974,-0.960960960960961,-0.9479479479479479,-0.934934934934935,-0.9219219219219219,-0.9089089089089089,-0.8958958958958959,-0.8828828828828829,-0.8698698698698699,-0.8568568568568569,-0.8438438438438438,-0.8308308308308309,-0.8178178178178178,-0.8048048048048049,-0.7917917917917918,-0.7787787787787788,-0.7657657657657657,-0.7527527527527528,-0.7397397397397397,-0.7267267267267268,-0.7137137137137137,-